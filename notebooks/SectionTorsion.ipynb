# %% [markdown]
# # Torsion Constant

# %%
from opensees import patch, section, layer, torsion

# %%
b, d = 1.5, 1
scale = 2
sect = patch.RegularPolygon(8, d)

# sect = patch.rect(vertices=[[-b/2,-d/2],[b/2,d/2]])
# sect = patch.circ(extRad=b)

#--------------------------
# d = 16
# scale=0.1
# sect = section.FiberSection(areas=[
#     patch.rect(corners=[[-8,  0],[-4, 16]]),
#     patch.rect(corners=[[ 4,  0],[ 8, 16]]),
#     patch.rect(corners=[[-4, 12],[4, 16]])
# ])

# %%
mesh = section.sect2gmsh(sect, [d/8]*2)

# %%
torsion.plot(mesh, torsion.solve_torsion(sect, mesh), scale=scale, show_edges=True)
# Out:
# 1.7255764937934668
# <div id='1004'>
#
#
#
#
#
#   <div class="bk-root" id="1a337d0f-d72b-4b89-9841-44c35782e4e9" data-root-id="1004"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"172cc1f3-dce8-41f0-9ed4-b4964b74f750":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"reload":false},"id":"1006","type":"panel.models.location.Location"},{"attributes":{},"id":"1003","type":"panel.models.vtk.VTKAxes"},{"attributes":{"client_comm_id":"dae5dee62ed44bafa7801cc9eaa1e894","comm_id":"bf3a310bd0ac4d5a9f8b00846da7cdcd","plot_id":"1004"},"id":"1005","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"0ae828ea0a2a8d0cd24d2e12b503bc44":"","3142e9870be1bce7aeea2c9ea02c3f98":"...","93287f91b2b489652c30f6168c3130c4":"...","aaeccf8365ecbff0f6a41c9c56d06ae2":"...","cd0d14a1f531442cfff8ea382dbb4d7c":"...","cf246c7a960aaffc56c08bef91de3ce6":"..."},"axes":{"id":"1003"},"color_mappers":[{"id":"1002"}],"margin":[5,5,5,5],"scene":{"calls":[["addRenderer",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17c20e6a0}"]],["addRenderer",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17c2ae6a0}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${000055a17c1fe6f0}"]],["addViewProp",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17bfb7ad0}"]]],"dependencies":[{"id":"000055a17c1fe6f0","parent":"717f026f-f4d8-4918-863c-fdd755e1b519000055a17c20e6a0","properties":{"clippingRange":[2.9948216220209205,8.62853891217628],"focalPoint":[0.0,0.0,0.00046552717685699463],"position":[3.1656650549245873,3.1656650549245873,3.1661305821014443],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17b7e91e0}"]],["setProperty",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17bfb6dd0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17b7e91e0-dataset-0}",0]],["setLookupTable",["instance:${717f026f-f4d8-4918-863c-fdd755e1b519000055a17a1778c0}"]]],"dependencies":[{"id":"717f026f-f4d8-4918-863c-fdd755e1b519000055a17b7e91e0-dataset-0","parent":"717f026f-f4d8-4918-863c-fdd755e1b519000055a17b7e91e0","properties":{"fields":[{"dataType":"Float64Array","hash":"cd0d14a1f531442cfff8ea382dbb4d7c","location":"pointData","name":"u","numberOfComponents":1,"ranges":[{"component":null,"max":0.05923829159115873,"min":-0.058772765576254035}],"registration":"setScalars","size":307,"vtkClass":"vtkDataArray"}],"lines":{"dataType":"Uint32Array","hash":"aaeccf8365ecbff0f6a41c9c56d06ae2","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":55.0,"min":0.0}],"size":168,"vtkClass":"vtkCellArray"},"points":{"dataType":"Float32Array","hash":"cf246c7a960aaffc56c08bef91de3ce6","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":1.0,"min":-1.0},{"component":null,"max":1.0,"min":-1.0},{"component":null,"max":0.11847658455371857,"min":-0.11754553020000458},{"component":null,"max":1.0823948767730607,"min":0.03864947155398655}],"size":921,"vtkClass":"vtkPoints"},"polys":{"dataType":"Uint32Arr ...
