# %% [markdown]
# # Circular Fiber Patterns

# %%
from opensees.section import patch, layer, SectionGeometry
from sees.section import render

# %% [markdown]
# - Cartesian Cookie Cutter
# - [Sunflower](https://stackoverflow.com/a/44164075/17981831)
# - [Modified sunflower](https://stackoverflow.com/a/28572551/17981831) - better boundary ([in Python](https://stackoverflow.com/a/71685455/17981831))
# - [method-2](https://orbi.uliege.be/bitstream/2268/91953/1/masset_isocell_orbi.pdf)

# %%
def test_rule(rule, divs):
    # Plot
    
    # check area sum
    
    # area stddev & mean
    pass

# %%
s = SectionGeometry(None, [patch.circ(intRad=5, extRad=20, divs=(10,10))])
render(s);

sum(f.area for f in s.fibers) - s.area
# Out:
# -9.094947017729282e-13

# %%
render(
    SectionGeometry(None, [
        patch.circ(intRad=4, extRad=20, divs=(8,20), rule="uniform-2")
    ])
);

# %%
render(
    SectionGeometry(None, [
        patch.circ(intRad=5., extRad=20, divs=(4,8,8), rule="uniform-4")
    ])
);

# %%
render(
    SectionGeometry(None, [
        patch.circ(intRad=2., extRad=20, divs=(1000,), rule="sunflower")
    ])
);
